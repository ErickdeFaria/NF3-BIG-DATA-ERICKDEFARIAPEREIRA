# %% [markdown]
# <a href="https://colab.research.google.com/github/ErickdeFaria/trabalhobigdata/blob/main/TERCEIRA_ENTREGA_TRABALHO_BIG_DATA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **3° EXERCICIO NOTA FINAL**
#
# **ERICK DE FARIA PEREIRA**
#
#  **MATRICULA: 202202965553**

# %% [markdown]
# ### **NUMERO 1:**
#
# **LETRA A**

# %%
##### NUMERO 1 LETRA A ####

import pandas as pd

dtf = pd.read_csv ('/content/sample_data/world_alcohol.csv',sep = ',')

agruparbebidas = dtf.groupby('Beverage Types')

for bebida, grupo in agruparbebidas:

    print(f"Bebida: {bebida}")

    print(grupo)

    print('\n')
# Out:
# Bebida: Beer
#     Year             WHO region                           Country  \
# 3   1986               Americas                          Colombia
# 4   1987               Americas             Saint Kitts and Nevis
# 11  1989               Americas                         Guatemala
# 12  1985        Western Pacific  Lao People's Democratic Republic
# 17  1989                 Africa                        Seychelles
# 19  1984                 Africa                             Kenya
# 23  1984                 Europe                            Turkey
# 27  1984  Eastern Mediterranean                           Bahrain
# 28  1987        Western Pacific                          Viet Nam
# 32  1989                 Africa                         Mauritius
# 36  1987  Eastern Mediterranean                             Egypt
# 37  1986                 Europe                            Sweden
# 41  1986                 Europe                    Czech Republic
# ...

# %% [markdown]
# **NUMERO 1:**
#
# **LETRA B**

# %%
#### NUMERO 1 LETRA B ####

agruparregiao = dtf.groupby(['Year','WHO region'])

for regiao, grupo in agruparregiao:

    print(f"Regiao: {regiao}")

    print(grupo)

    print('\n')
# Out:
# Regiao: (1984, 'Africa')
#     Year WHO region            Country Beverage Types  Display Value
# 9   1984     Africa            Nigeria          Other           6.10
# 19  1984     Africa              Kenya           Beer           1.08
# 95  1984     Africa              Niger          Other           0.00
# 98  1984     Africa  Equatorial Guinea           Wine           0.00
#
#
# Regiao: (1984, 'Americas')
#     Year WHO region      Country Beverage Types  Display Value
# 16  1984   Americas   Costa Rica           Wine           0.06
# 54  1984   Americas  El Salvador        Spirits           1.81
#
#
# Regiao: (1984, 'Eastern Mediterranean')
#     Year             WHO region      Country Beverage Types  Display Value
# 13  1984  Eastern Mediterranean  Afghanistan          Other           0.00
# 25  1984  Eastern Mediterranean      Tunisia          Other           0.00
# 27  1984  Eastern Mediterranean      Bahrain           Beer           2.22
# ...

# %% [markdown]
# **NUMERO 1:**
#
# **LETRA C**

# %%
#### NUMERO 1 LETRA D ####


ctg_regioes = dtf.groupby('WHO region').size()


print("ocorrências por Região: ")

print(ctg_regioes)

print('\n')


contagem_paises = dtf.groupby('Country').size()


print("Contagem de ocorrências por País:")

print(ctg_regioes)

print('\n')


valor = dtf.groupby('Beverage Types') ['Display Value'].sum()


print("valores por Bebida: ")

print(valor)
# Out:
# ocorrências por Região:
# WHO region
# Africa                   29
# Americas                 19
# Eastern Mediterranean    18
# Europe                   22
# South-East Asia           4
# Western Pacific           8
# dtype: int64
#
#
# Contagem de ocorrências por País:
# WHO region
# Africa                   29
# Americas                 19
# Eastern Mediterranean    18
# Europe                   22
# South-East Asia           4
# Western Pacific           8
# dtype: int64
#
#
# valores por Bebida:
# Beverage Types
# Beer       35.50
# Other      14.93
# Spirits    30.97
# Wine       23.39
# Name: Display Value, dtype: float64

# %% [markdown]
# **NUMERO 1:**
#
# **LETRA D**

# %%
#### NUMERO 1 LETRA D ####


anls_valores = dtf['Display Value'].describe()


print("Analise estatistica: ")

print(anls_valores)

print('\n')


media_por_bebida = dtf.groupby('Beverage Types') ['Display Value'].mean()


print('media por tipo de bebida: ')

print(media_por_bebida)

print('\n')


moda_por_bebida = dtf.groupby('Beverage Types')['Display Value'].apply(lambda x: x.mode ().iloc[0])


print('moda por tipo de bebida: ')

print(moda_por_bebida)

print('\n')


mediana_por_bebida = dtf.groupby('Beverage Types')['Display Value'].median()


print('mediana por tipo de bebida: ')

print(mediana_por_bebida)

print('\n')
# Out:
# Analise estatistica:
# count    95.000000
# mean      1.103053
# std       1.642623
# min       0.000000
# 25%       0.000000
# 50%       0.190000
# 75%       1.820000
# max       7.380000
# Name: Display Value, dtype: float64
#
#
# media por tipo de bebida:
# Beverage Types
# Beer       1.479167
# Other      0.649130
# Spirits    1.474762
# Wine       0.866296
# Name: Display Value, dtype: float64
#
#
# moda por tipo de bebida:
# Beverage Types
# Beer       0.0
# Other      0.0
# Spirits    0.0
# Wine       0.0
# Name: Display Value, dtype: float64
#
#
# mediana por tipo de bebida:
# Beverage Types
# Beer       0.66
# Other      0.00
# Spirits    1.62
# Wine       0.04
# Name: Display Value, dtype: float64

# %% [markdown]
# **NUMERO 1:**
#
# **LETRA E**

# %%
#### NUMERO 1 LETRA E PARTE 1 ####


ano = dtf.loc[dtf['Year'] == 1985, 'Beverage Types']

ano
# Out:
# 2        Wine
# 7     Spirits
# 12       Beer
# 14    Spirits
# 24      Other
# 26       Wine
# 33      Other
# 35    Spirits
# 44      Other
# 50      Other
# 63      Other
# 71      Other
# 76       Beer
# 77    Spirits
# 80      Other
# 81       Wine
# 85       Wine
# 94    Spirits
# 96       Wine
# 99       Wine
# Name: Beverage Types, dtype: object

# %%
#### NUMERO 1 LETRA E PARTE 2 ####


vlr = dtf.loc[dtf['Display Value'] > 4, 'WHO region']

vlr
# Out:
# 3     Americas
# 9       Africa
# 21    Americas
# 30      Africa
# 41      Europe
# 57      Europe
# 91      Europe
# 96      Europe
# Name: WHO region, dtype: object

# %% [markdown]
# ### ***NUMERO 2***

# %%
#### NUMERO 1 #####

import pandas as pd


dtf = pd.read_csv('https://raw.githubusercontent.com/ErickdeFaria/trabalhobigdata/main/cursos-prouni.csv',encoding='latin', sep =';')


dtf
# Out:
#                grau              turno mensalidade  bolsa_integral_cotas  \
# 0       Bacharelado           Integral     9999,99                  15.0
# 1       Bacharelado            Noturno      9836,4                   1.0
# 2       Bacharelado           Integral     9715,61                   2.0
# 3       Bacharelado            Noturno     9689,34                   3.0
# 4       Bacharelado           Integral     9674,34                   4.0
# ...             ...                ...         ...                   ...
# 41442  Licenciatura  Curso a Distância         149                   1.0
# 41443   Tecnológico  Curso a Distância         144                   1.0
# 41444   Tecnológico         Vespertino         139                   1.0
# 41445   Bacharelado  Curso a Distância         139                   1.0
# 41446   Tecnológico  Curso a Distância         139                   3.0
#
#        bolsa_integral_ampla  bolsa_parcial_cotas  bolsa_parcial_ampla  \
# ...

# %% [markdown]
# **LETRA A**

# %%
#### NUMERO 2 LETRA A ####

import numpy as np


colunas_notas = ['nota_integral_ampla', 'nota_integral_cotas', 'nota_parcial_ampla', 'nota_parcial_cotas',]


dtf[colunas_notas] = dtf[colunas_notas].fillna(0.0)

dtf
# Out:
#                grau              turno mensalidade  bolsa_integral_cotas  \
# 0       Bacharelado           Integral     9999,99                  15.0
# 1       Bacharelado            Noturno      9836,4                   1.0
# 2       Bacharelado           Integral     9715,61                   2.0
# 3       Bacharelado            Noturno     9689,34                   3.0
# 4       Bacharelado           Integral     9674,34                   4.0
# ...             ...                ...         ...                   ...
# 41442  Licenciatura  Curso a Distância         149                   1.0
# 41443   Tecnológico  Curso a Distância         144                   1.0
# 41444   Tecnológico         Vespertino         139                   1.0
# 41445   Bacharelado  Curso a Distância         139                   1.0
# 41446   Tecnológico  Curso a Distância         139                   3.0
#
#        bolsa_integral_ampla  bolsa_parcial_cotas  bolsa_parcial_ampla  \
# ...

# %% [markdown]
# **LETRA B**

# %%
#### NUMERO 2 LETRA B ####

grau = dtf.groupby('grau')

for grau, dds in grau:
  print('Grau:', grau)
  print(dds)
  print('\n')
# Out:
# Grau: Bacharelado
#               grau              turno mensalidade  bolsa_integral_cotas  \
# 0      Bacharelado           Integral     9999,99                  15.0
# 1      Bacharelado            Noturno      9836,4                   1.0
# 2      Bacharelado           Integral     9715,61                   2.0
# 3      Bacharelado            Noturno     9689,34                   3.0
# 4      Bacharelado           Integral     9674,34                   4.0
# ...            ...                ...         ...                   ...
# 41098  Bacharelado  Curso a Distância         169                   1.0
# 41100  Bacharelado  Curso a Distância         169                   0.0
# 41101  Bacharelado  Curso a Distância         169                   0.0
# 41103  Bacharelado  Curso a Distância         169                   0.0
# 41445  Bacharelado  Curso a Distância         139                   1.0
#
#        bolsa_integral_ampla  bolsa_parcial_cotas  bolsa_parcial_ampla  \
# ...

# %% [markdown]
# **LETRA C**

# %%
#### NUMERO 2 LETRA C ####


crs = ['Matemática','Medicina','Pedagogia']

flt = dtf.loc[dtf['curso_busca'].isin(crs)]

flt
# Out:
#                grau              turno mensalidade  bolsa_integral_cotas  \
# 0       Bacharelado           Integral     9999,99                  15.0
# 2       Bacharelado           Integral     9715,61                   2.0
# 4       Bacharelado           Integral     9674,34                   4.0
# 5       Bacharelado           Integral        9650                   8.0
# 6       Bacharelado           Integral        9564                   3.0
# ...             ...                ...         ...                   ...
# 41084  Licenciatura  Curso a Distância         169                  18.0
# 41096  Licenciatura  Curso a Distância         169                   0.0
# 41099  Licenciatura  Curso a Distância         169                   1.0
# 41102  Licenciatura  Curso a Distância         169                   0.0
# 41104  Licenciatura  Curso a Distância         169                   0.0
#
#        bolsa_integral_ampla  bolsa_parcial_cotas  bolsa_parcial_ampla  \
# ...

# %% [markdown]
# **LETRA D**

# %%
#### NUMERO 2 LETRA D ####

nota_media = dtf.groupby('uf_busca')[['nota_integral_ampla', 'nota_integral_cotas', 'nota_parcial_ampla', 'nota_parcial_cotas']].mean(numeric_only=True)

print(nota_media)
# Out:
#           nota_integral_ampla  nota_integral_cotas
# uf_busca
# AC                  68.500000             7.342105
# AL                  41.263158            16.523810
# AM                  96.166667            24.098361
# AP                  60.060000            14.169355
# BA                  45.610592            10.901173
# CE                  23.361991             7.880000
# DF                  87.326203            10.303279
# ES                  56.252874            11.756579
# GO                 100.929619            26.734332
# MA                  47.224242             4.119266
# MG                  96.494505            15.990316
# MS                 114.548263            53.464819
# MT                 130.765193            27.128671
# PA                  39.125668             7.230024
# PB                  86.273684            24.871094
# PE                  33.495902            22.131679
# PI                  29.716667            10.383721
# ...

# %% [markdown]
# **LETRA E**

# %%
#### NUMERO 2 LETRA E ####


crs = ['Tecnológico']
flt = dtf.loc[dtf['grau'].isin(crs)]

flt
# Out:
#               grau              turno mensalidade  bolsa_integral_cotas  \
# 151    Tecnológico            Noturno     4279,28                   0.0
# 154    Tecnológico            Noturno     4138,34                   1.0
# 214    Tecnológico            Noturno        3420                   1.0
# 216    Tecnológico            Noturno      3408,1                   1.0
# 230    Tecnológico         Vespertino     3311,38                   0.0
# ...            ...                ...         ...                   ...
# 41440  Tecnológico  Curso a Distância         149                   0.0
# 41441  Tecnológico  Curso a Distância         149                   0.0
# 41443  Tecnológico  Curso a Distância         144                   1.0
# 41444  Tecnológico         Vespertino         139                   1.0
# 41446  Tecnológico  Curso a Distância         139                   3.0
#
#        bolsa_integral_ampla  bolsa_parcial_cotas  bolsa_parcial_ampla  \
# ...

# %% [markdown]
# **LETRA F**

# %%
#### NUMERO 2 LETRA F ####


dtf = dtf.drop("cidade_filtro", axis = 1)

dtf
# Out:
#                grau              turno mensalidade  bolsa_integral_cotas  \
# 0       Bacharelado           Integral     9999,99                  15.0
# 1       Bacharelado            Noturno      9836,4                   1.0
# 2       Bacharelado           Integral     9715,61                   2.0
# 3       Bacharelado            Noturno     9689,34                   3.0
# 4       Bacharelado           Integral     9674,34                   4.0
# ...             ...                ...         ...                   ...
# 41442  Licenciatura  Curso a Distância         149                   1.0
# 41443   Tecnológico  Curso a Distância         144                   1.0
# 41444   Tecnológico         Vespertino         139                   1.0
# 41445   Bacharelado  Curso a Distância         139                   1.0
# 41446   Tecnológico  Curso a Distância         139                   3.0
#
#        bolsa_integral_ampla  bolsa_parcial_cotas  bolsa_parcial_ampla  \
# ...

# %% [markdown]
# **LETRA G**

# %%
#### NUMERO 2 LETRA G ####


dtf['mensalidade'] = dtf['mensalidade'].astype(str)

dtf['mensalidade'] = dtf['mensalidade'].str.replace ('[^\d.]', '', regex=True)

dtf['mensalidade'] = pd.to_numeric(dtf['mensalidade'])


media = dtf[dtf['curso_busca'] == 'Medicina']['mensalidade'].mean()


media
# Out:
# 325928.8064516129

# %% [markdown]
# **LETRA H**

# %%
#### NUMERO 2 LETRA H ####


import numpy as np

media_integral = ['nota_integral_ampla', 'nota_integral_cotas']

flt = dtf['turno'] == 'Integral'


dtf[media_integral] = dtf[media_integral].apply(lambda x: pd.to_numeric(x, errors='coerce'))


media_ampla = dtf[flt]['nota_integral_ampla'].mean()

media_cotas = dtf[flt]['nota_integral_cotas'].mean()


print("Média amplas: ", media_ampla)

print("Média cotas: ", media_cotas)
# Out:
# Média amplas:  88.3076923076923
# Média cotas:  38.71167883211679

# %% [markdown]
# **LETRA I**

# %%
#### NUMERO 2 LETRA I ####


filtro = dtf['grau'] == 'Bacharelado'

tipos_integral = ['nota_integral_ampla','nota_integral_cotas']

integral_bacharel = dtf[filtro][tipos_integral]


estatistica = integral_bacharel.describe()


estatistica
# Out:
#        nota_integral_ampla  nota_integral_cotas
# count          3900.000000          9867.000000
# mean             88.130000            28.864092
# std             200.788776           118.904188
# min               0.000000             0.000000
# 25%               0.000000             0.000000
# 50%               0.000000             0.000000
# 75%               0.000000             0.000000
# max             747.000000           749.000000

# %% [markdown]
# **LETRA J**

# %%
#### NUMERO 2 LETRA J ####


import matplotlib.pyplot as plt

dtf['nota_integral_cotas'] = pd.to_numeric (dtf['nota_integral_cotas'], errors='coerce')

integral = dtf.groupby('grau') ['nota_integral_cotas'].mean()

integral.plot.bar()


plt.xlabel('Grau dos Cursos')

plt.ylabel('Notas de Corte')

plt.title('Comparação das Notas de Corte por Grau')

plt.show()
